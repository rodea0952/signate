# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
sns.set(font="Yu Gothic", style="white")
plt.style.use("ggplot")

# %%
train_df = pd.read_csv("train.csv")
test_df = pd.read_csv("test.csv")
submission_df = pd.read_csv("sample_submission.csv", header=None)

# %%
train_df.head(10)
# Out:
#    id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0   0           1203     0     0.680981         1   1       1          23
# 1   3           1203     1     2.602754         1   0       0           8
# 2   4           1980     1     2.604065         1   0       0           6
# 3   5           1185     1     2.669403         1   3       0          33
# 4   7           1203     1     2.375453         0   4       1          12
# 5   8           1203     1     0.499105         0   2       0          53
# 6   9           1977     1     0.512764         1   3       1           3
# 7  11           1154     0     0.499018         0   0       0           2
# 8  14           1949     1     1.109262         1   0       0          27
# 9  16           1027     1     1.682319         1   0       1          60
#
#       m_dep  mobile_wt  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# ...

# %%
test_df.head(10)
# Out:
#    id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0   1           1203     0     0.498993         1   0       1          40
# 1   2           1154     0     1.981014         0   1       0          33
# 2   6           1027     1     1.647026         0   0       1          32
# 3  10            833     0     1.070061         0   0       0           2
# 4  12           1027     1     1.859165         0   4       1           2
# 5  13           1537     0     2.343562         1   0       1          27
# 6  15           1027     0     1.762663         0   0       0          49
# 7  18           1537     1     1.092578         0   1       1          32
# 8  23           1203     1     0.499424         0   4       0           6
# 9  24           1271     1     2.582454         0   0       0          60
#
#       m_dep  mobile_wt  ...  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0  0.914530        190  ...   7        381       721  1970     6     1
# ...

# %%
all_df = pd.concat([train_df, test_df], sort=False).reset_index(drop=True)

# %%
all_df
# Out:
#         id  battery_power  blue  clock_speed  dual_sim  fc  four_g  \
# 0        0           1203     0     0.680981         1   1       1
# 1        3           1203     1     2.602754         1   0       0
# 2        4           1980     1     2.604065         1   0       0
# 3        5           1185     1     2.669403         1   3       0
# 4        7           1203     1     2.375453         0   4       1
# ...    ...            ...   ...          ...       ...  ..     ...
# 1995  1978           1537     0     1.652838         0   0       1
# 1996  1980            710     1     0.575525         0   0       0
# 1997  1982           1185     1     0.498563         1   0       0
# 1998  1988            710     0     0.498750         1   0       1
# 1999  1998            710     0     0.498790         1   0       1
#
#       int_memory     m_dep  mobile_wt  ...  px_height  px_width   ram  sc_h  \
# 0             23  0.402580        117  ...       1331       721  1970    15
# ...

# %%
train_df_le = all_df[~all_df["price_range"].isnull()]
test_df_le = all_df[all_df["price_range"].isnull()]
train_X = train_df_le.drop(["id", "price_range"], axis=1)
train_Y = train_df_le["price_range"]

# %%
import lightgbm as lgb
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import f1_score

kf = StratifiedKFold(n_splits=4, shuffle=True, random_state=952)

# %%
lgbm_params = {
    "task": "train",
    "boosting_type": "gbdt",
    "objective": "multiclass",
    "num_class": 4
}

# %%
models = []
f1_scores = []
oof = np.zeros(len(train_X))

for tr_idx, va_idx in kf.split(train_X, train_Y):
    tr_x, va_x = train_X.iloc[tr_idx], train_X.iloc[va_idx]
    tr_y, va_y = train_Y.iloc[tr_idx], train_Y.iloc[va_idx]
        
    lgb_train = lgb.Dataset(tr_x, tr_y)
    lgb_eval = lgb.Dataset(va_x, va_y, reference=lgb_train)

    model_lgb = lgb.train(lgbm_params,
                          lgb_train,
                          valid_sets=lgb_eval,
                          valid_names=["train", "valid"],
                          num_boost_round=100,
                          early_stopping_rounds=20,
                          verbose_eval=10
                         )    
    
    y_pred = model_lgb.predict(va_x, num_iteration=model_lgb.best_iteration)
    y_pred = np.argmax(y_pred, axis=1)
    tmp_f1_score = f1_score(va_y, y_pred, average='macro')
    print("f1_score", tmp_f1_score)    

    models.append(model_lgb)    
    f1_scores.append(tmp_f1_score)
    oof[va_idx] = y_pred
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000883 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1017
# [LightGBM] [Info] Number of data points in the train set: 900, number of used features: 20
# [LightGBM] [Info] Start training from score -1.733491
# [LightGBM] [Info] Start training from score -1.386294
# [LightGBM] [Info] Start training from score -1.049822
# [LightGBM] [Info] Start training from score -1.499090
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 20 rounds
# [10]	train's multi_logloss: 1.19367
# [20]	train's multi_logloss: 1.20093
# [30]	train's multi_logloss: 1.21901
# Early stopping, best iteration is:
# ...

# %%
np.mean(f1_scores)
# Out:
# 0.4575168041439218

# %%
for model in models:
    lgb.plot_importance(model, importance_type="gain", max_num_features=20)

# %%
all_df["px_S"] = all_df["px_height"] * all_df["px_width"]
all_df["sc_S"] = all_df["sc_h"] * all_df["sc_w"]

# %%
train_df_le = all_df[~all_df["price_range"].isnull()]
test_df_le = all_df[all_df["price_range"].isnull()]
train_X = train_df_le.drop(["id", "price_range"], axis=1)
train_Y = train_df_le["price_range"]

# %%
lgbm_params = {
    "alpha": 100,
    "boosting_type": "gbdt",
    "colsample_bytree": 0.8,
    "colsample_bylevel": 0.3,
    "eta": 0.05,
    "gamma": 0.1,
    "importance_type": "split",
    "lambda": 1.0,
    "learning_rate": 0.05,
    "max_bin": 331,
    "max_depth": 5,
    "min_child_samples": 2,
    "min_child_weight": 2,
    "n_estimators": 200,
    "n_jobs": -1,
    "num_leaves": 3,
    "num_class": 4,
    "min_data_in_leaf": 57,
    "objective": "multiclass",
    "random_seed": 952,
    "reg_alpha": 0.01,
    "reg_lambda": 0.01,
    "silent": True,
    "subsample": 0.9
}

# %%
models = []
f1_scores = []
oof = np.zeros(len(train_X))

for tr_idx, va_idx in kf.split(train_X, train_Y):
    tr_x, va_x = train_X.iloc[tr_idx], train_X.iloc[va_idx]
    tr_y, va_y = train_Y.iloc[tr_idx], train_Y.iloc[va_idx]
        
    lgb_train = lgb.Dataset(tr_x, tr_y)
    lgb_eval = lgb.Dataset(va_x, va_y, reference=lgb_train)

    model_lgb = lgb.train(lgbm_params,
                          lgb_train,
                          valid_sets=lgb_eval,
                          valid_names=["train", "valid"],
                          num_boost_round=100,
                          early_stopping_rounds=20,
                          verbose_eval=10
                         )    
    
    y_pred = model_lgb.predict(va_x, num_iteration=model_lgb.best_iteration)
    y_pred = np.argmax(y_pred, axis=1)
    tmp_f1_score = f1_score(va_y, y_pred, average='macro')
    print("f1_score", tmp_f1_score)    

    models.append(model_lgb)    
    f1_scores.append(tmp_f1_score)
    oof[va_idx] = y_pred
# Out:
# C:\Users\drago\Anaconda3\lib\site-packages\lightgbm\engine.py:148: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning("Found `{}` in params. Will use it instead of argument".format(alias))
# C:\Users\drago\Anaconda3\lib\site-packages\lightgbm\basic.py:1224: UserWarning: silent keyword has been found in `params` and will be ignored.
# Please use silent argument of the Dataset constructor to pass this parameter.
#   .format(key))
# [LightGBM] [Warning] Unknown parameter: colsample_bylevel
# [LightGBM] [Warning] Unknown parameter: gamma
# [LightGBM] [Warning] Unknown parameter: importance_type
# [LightGBM] [Warning] lambda_l2 is set with lambda=1.0, reg_lambda=0.01 will be ignored. Current value: lambda_l2=1.0
# [LightGBM] [Warning] Unknown parameter: silent
# [LightGBM] [Warning] learning_rate is set=0.05, eta=0.05 will be ignored. Current value: learning_rate=0.05
# ...

# %%
np.mean(f1_scores)
# Out:
# 0.4737639914101104

# %%
all_df0 = all_df[all_df["price_range"] == 0]
all_df0.describe().T
# Out:
#                count           mean            std          min  \
# id             212.0    1023.976415     546.164849     7.000000
# battery_power  212.0    1185.976415     404.701533   518.000000
# blue           212.0       0.528302       0.500380     0.000000
# clock_speed    212.0       1.620765       0.848193     0.467195
# dual_sim       212.0       0.429245       0.496140     0.000000
# fc             212.0       1.547170       2.609251     0.000000
# four_g         212.0       0.551887       0.498478     0.000000
# int_memory     212.0      27.575472      17.901229     2.000000
# m_dep          212.0       0.418093       0.314619     0.021539
# mobile_wt      212.0     140.160377      32.094687    80.000000
# n_cores        212.0       4.561321       2.470876     1.000000
# pc             212.0       7.193396       5.949659     0.000000
# px_height      212.0     550.811321     366.366458     4.000000
# px_width       212.0    1321.834906     402.550761   510.000000
# ...

# %%
test_X = pd.DataFrame(test_df_le)
test_X = test_X.drop(["id", "price_range"], axis=1)

# %%
preds = []
for model in models:
    pred = model.predict(test_X)
    pred = np.argmax(pred, axis=1)
    preds.append(pred)

# %%
preds = np.array(preds).T

# %%
submit = []
for i in range(len(preds)):
    cnt = [0] * 4
    for j in range(4):
        cnt[preds[i][j]] += 1
    if 2 <= cnt[2]:
        submit.append(2)
    elif 2 <= cnt[1]:
        submit.append(1)
    elif 2 <= cnt[3]:
        submit.append(3)
    elif 2 <= cnt[0]:
        submit.append(0)
    else:
        submit.append(2)

# %%
n_target0, n_target1, n_target2, n_target3 = len(train_df[train_df['price_range'] == 0]), len(train_df[train_df['price_range'] == 1]), len(train_df[train_df['price_range'] == 2]), len(train_df[train_df['price_range'] == 3])
n_all = n_target0 + n_target1 + n_target2 + n_target3
print('0 の割合 :', n_target0 / n_all, submit.count(0) / len(submit))
print('1 の割合 :', n_target1 / n_all, submit.count(1) / len(submit))
print('2 の割合 :', n_target2 / n_all, submit.count(2) / len(submit))
print('3 の割合 :', n_target3 / n_all, submit.count(3) / len(submit))
# Out:
# 0 の割合 : 0.17666666666666667 0.115
# 1 の割合 : 0.25 0.35
# 2 の割合 : 0.35 0.325
# 3 の割合 : 0.22333333333333333 0.21

# %%
submission_df[1] = submit

# %%
submission_df
# Out:
#         0  1
# 0       1  3
# 1       2  2
# 2       6  3
# 3      10  1
# 4      12  1
# ..    ... ..
# 795  1978  3
# 796  1980  1
# 797  1982  3
# 798  1988  2
# 799  1998  2
#
# [800 rows x 2 columns]

# %%
submission_df.to_csv("lightgbm03.csv", index=False)
